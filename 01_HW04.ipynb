# %%
NAME = "AMNA KHALID"

# %%
def structures():
    """Purpose:open the Inscriptions.csv data file
    and load it into a 2D data structure (list of lists, where each row
    of data is an inner list)
    Parameters: None
    Return value: list of lists"""
    
    fh = open("OCBG_CWBryant_Inscriptions.csv", "r")
    
    All = []
    page = []
    ordr = []
    bry =[]
    lnames = []
    fnames =[]
    MI = []
    born = []
    died = []
    age_death = []
    title = []
    spouse = []
    father = []
    mother = []
    maiden_name = []
    d_o_b = []
    Death_Date = []
    Aged = []
    Months = []
    Days = []
    Place_of_Birth= []
    Place_of_Death = []
    e = []
    Location =[]
    Compare_with =[]
    
    header = fh.readline().strip().split(',')
    #header.remove(header[22])
    #header.remove(header[22])
    #All.append(header)
    #print(header)
    for line in fh:
        row = line.strip().split(',')
        page.append(row[0])
        ordr.append(row[1])
        bry.append(row[2])
        lnames.append(row[3])
        fnames.append(row[4])
        MI.append(row[5])
        born.append(row[6])
        died.append(row[7])
        age_death.append(row[8])
        title.append(row[9])
        spouse.append(row[10])
        father.append(row[11])
        mother.append(row[12])
        maiden_name.append(row[13])
        d_o_b.append(row[14])
        Death_Date.append(row[15])
        Aged.append(row[16])
        Months.append(row[17])
        Days.append(row[18])
        Place_of_Birth.append(row[19])
        Place_of_Death.append(row[20])
        e.append(row[21])
        Location.append(row[22])
        Compare_with.append(row[23])
        
        All.append([row[0], row[1], row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[9], row[10], row[11], row[12], row[13], row[14], row[15], row[16], row[17], row[18],  row[19], row[20], row[21], row[22], row[23]])
    
    
    
    
    fh.close()
    
    return All

# %%
All = structures()

# %%
def why():
    """Purpose: open the Inscriptions.csv data file 
    and load it into a 2D data structure (dictionary of lists, where each column 
    is an inner list)
    Parameters: None
    Return value: dictionary of lists
    """
    fh = open("OCBG_CWBryant_Inscriptions.csv", "r")
    
    All = []
    page = []
    ordr = []
    bry =[]
    lnames = []
    fnames =[]
    MI = []
    born = []
    died = []
    age_death = []
    title = []
    spouse = []
    father = []
    mother = []
    maiden_name = []
    d_o_b = []
    Death_Date = []
    Aged = []
    Months = []
    Days = []
    Place_of_Birth= []
    Place_of_Death = []
    e = []
    Location =[]
    Compare_with =[]
    
    header = fh.readline().strip().split(',')
    header.remove(header[22])
    header.remove(header[22])
    
    for line in fh:
        row = line.strip().split(',')
        page.append(row[0])
        ordr.append(row[1])
        bry.append(row[2])
        lnames.append(row[3])
        fnames.append(row[4])
        MI.append(row[5])
        born.append(row[6])
        died.append(row[7])
        age_death.append(row[8])
        title.append(row[9])
        spouse.append(row[10])
        father.append(row[11])
        mother.append(row[12])
        maiden_name.append(row[13])
        d_o_b.append(row[14])
        Death_Date.append(row[15])
        Aged.append(row[16])
        Months.append(row[17])
        Days.append(row[18])
        Place_of_Birth.append(row[19])
        Place_of_Death.append(row[20])
        e.append(row[21])
        Location.append(row[22])
        Compare_with.append(row[23])
        
    jesus ={}
    
    jesus[header[0]] = page
    jesus[header[1]] = ordr
    jesus[header[2]] = bry
    jesus[header[3]] = lnames
    jesus[header[4]] = fnames
    jesus[header[5]] = MI
    jesus[header[6]] = born
    jesus[header[7]] = died
    jesus[header[8]] = age_death
    jesus[header[9]] = title
    jesus[header[10]] = spouse
    jesus[header[11]] = father
    jesus[header[12]] = mother
    jesus[header[13]] = maiden_name
    jesus[header[14]] = d_o_b
    jesus[header[15]] = Death_Date
    jesus[header[16]] = Aged
    jesus[header[17]] = Months
    jesus[header[18]] = Days
    jesus[header[19]] = Place_of_Birth
    jesus[header[20]] = Place_of_Death
    jesus[header[21]] = e
    jesus[header[22]] = Location
    jesus[header[23]] = Compare_with
    
    fh.close()
    
    return jesus

# %%
jesus = why()

# %%
def row_1(row_num):
    """Purpose: to get a single row of the data in a list 
    Parameters: row_num, the row number you want
    Return value: certain row that you want
    """
    return All[row_num]

# %%
def row_2(row_num):
    """Purpose: to get a single row of the data from the dictionary 
    Parameters:row_name, the number of the row you want
    Return value: certain row that you want
    """
    lol = []
    for key,val in jesus.items():
        lol.append(val[row_num])
    return lol

# %%
def col_1(column_name):
    """Purpose: to get a single column of the data, per each data structure
    Parameters:column_name, the name of the column you want
    Return value: certain values in the column that you want
    """
    return jesus[column_name]

# %%
def col_2(column_name):
    """Purpose: to get a single column of the data from a list
    Parameters:column_name, the name of the column you want
    Return value: certain column that you want
    """
    
    if column_name == "Page #":
        return [row[0] for row in All]
    if column_name == "Original Order Listed":
        return [row[1] for row in All]
    elif column_name == "Bryant Number":
        return [row[2] for row in All]
    elif column_name == "Name_Last":
        print([row[3] for row in All])
    elif column_name == "Name_First":
        return [row[4] for row in All]
    elif column_name == "Middle Initial":
        return [row[5] for row in All]
    elif column_name == "Born":
        return [row[6] for row in All]
    elif column_name == "Died":
        return [row[7] for row in All]
    elif column_name == "Approximate Age at Death":
        return [row[8] for row in All]
    elif column_name == "Title":
        return [row[9] for row in All]
    elif column_name == "Spouse":
        return [row[10] for row in All]
    elif column_name == "Father":
        return [row[11] for row in All]
    elif column_name == "Mother":
        return [row[12] for row in All]
    elif column_name == "Maiden Name":
        return [row[13] for row in All]
    elif column_name == "Birth Date":
        return [row[14] for row in All]
    elif column_name == "Death Date":
        return [row[15] for row in All]
    elif column_name == "Aged":
        return [row[16] for row in All]
    elif column_name == "Months":
        return [row[17] for row in All]
    elif column_name == "Days":
        return [row[18] for row in All]
    elif column_name == "Place of Birth":
        return [row[19] for row in All]
    elif column_name == "Place of Death":
        return [row[20] for row in All]
    elif column_name == "Epitaph":
        return [row[21] for row in All]
    elif column_name == "Location":
        return [row[22] for row in All]
    elif column_name == "Compare With":
        return [row[23] for row in All]
    else:
        return None

# %%
def xeeENDD():
    """Purpose: to test all the functions
    Parameters: None 
    Return value: None"""

    x = col_1("Name_Last")
    y = col_2("Name_Last")
    z = row_1(0)
    w = row_2(0)
    
    assert len(All) == len(jesus["Name_First"]) == 977
    assert len(jesus) == 24
    assert z == w
    assert x == y
